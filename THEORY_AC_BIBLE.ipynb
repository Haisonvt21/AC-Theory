# %% [markdown]
#                            This is theory AC test note

# %% [markdown]
# ////////////////////////////////                 BLOCK DIAGRAM                   ///////////////////////////////////////////
#
# Mindful about Cascade form and Parallel form
# But actually more likely to be Feedback form.
#
# 1. Characteristic equation
# 2. formula of feedback control system
# 3. Reduction techniques

# %%
from IPython import display
display.Image("./1.png")

# this is the characteristic equation of feedback loop

# %%
display.Image("./2.png")
# Use the first 3 rows

# %%
display.Image("./3.png")
# addition to the above

# %%
display.Image("./4.png")
# Reduction techniques

# %% [markdown]
# ////////////////////////////////////                 STABILITY                   ///////////////////////////////////////////
#
# So the stability has a lots to discuss:
#
# 1. BIBO stability
# 2. Routh-Huzwitz criterion
# 3. Marginally stability
# 4. exponential stability
# 5. lyapunov stability
#
# ***note: internal vs external stability
#
# Internal: state space representation
# External: transfer function (realization)
#
# ***note: https://www.youtube.com/watch?v=pBinplE_6hg is reference for root locus analysis

# %%
# BIBO stability
display.Image("./5.png")

# %%
# Routh-Huwitz /// compute in Matlab file
display.Image("./6.png")

# %%
# Routh formula in case we have to find a range of values for K 
# NOTICE: there is no such thing a = 0, only a = epsilon
display.Image("./7.png")

# %% [markdown]
# ***Marginally stable when homogeneous sol of state space (aka dx/dt = Ax) = x0 (aka uniform bound)
#
# ***Now go beyond that, if the above sol after a long time goes to 0, BOOM you have asymptotical stable
#
#
# ***Exponentional stable: eienvalues have strictly negative real parts.
#
#
# ***Internal stability (aka Lyapunov) satisfies all of these above and some
# nonchalant shit (5 total)

# %% [markdown]
# # state space minimal realization:
# # aka Controlable (A B) and Observable (A C)
#
# # include in the MATLAB file

# %% [markdown]
# /////////////////////////////////// RESPONSE OF THE LTI SYSTEM ///////////////////////////////////
#
# reference source for matlab: https://ctms.engin.umich.edu/CTMS/index.php?example=Introduction&section=SystemAnalysis
#
# so basically the subject divides itself to these concerns:
# 1. what is the response of the sys when we input special defined easily computed easily measured signal (aka ramp, step, dirac, parabolic)
# 2. Then we have to classify which regions are  transient or steady state
# 3. but there are many characteristics aside: settling time, rise time, dc gain, time constant,...
#
# # Transient only depend upon the sys poles
# # Laplace transform of impulse response is transfer function

# %%
# Test signal and their laplace transform
display.Image("./8.png")

# %%
############################################# 1ST ORDER SYS #############################################################
display.Image("./9.png")

# %%
# Settling, time constant, and rise time
display.Image("./10.png")

# %%
display.Image("./11.jpg")

# %%
# Partial fraction in matlab file

# %%
# Step response (forced and natural)
display.Image("./12.png")

# %%
# ramp response
display.Image("./13.png")

# %%
# parabolic response
display.Image("./14.png")

# %% [markdown]
# # Practical determination of transfer function of 1st order sys
#
# Basically there will be a plot of the response. And 2 things to look for: final value and time const = 0.63*(final value)

# %% [markdown]
# # 1st order response with zeros in pdf file
# # recommend using stimulink
# # remind: if first order with delay time: delay 2s means 1 in simulink

# %%
# example with steady state error
display.Image("./15.png")

# %% [markdown]
# # sol
#
# # recommend see through: https://electricalworkbook.com/unit-ramp-response-first-order-control-system/

# %%
display.Image("./16.jpg")

# %%
############################################# SECOND ORDER SYS #############################################################


# In general, it all boils down to the damping ratio and un-damped natural frequency

# %%
# basic of 2nd order sys
display.Image("./17.png")

# %%
# Sol to second order sys (damping, frequency)
display.Image("./24.png")

# %%
# overdamped: damping ratio > 1, two distinct real roots
# underdamped: 0<damping ratio<1, two conjugate complex roots
# undamped: damping ratio = 0, two img roots
# critically damped: damping ratio = 1, two real double roots

# %%
# underdamped response:
display.Image("./18.png")

# %%
# delay time td
display.Image("./19.png")

# %%
# rise time
display.Image("./20.png")

# %%
# peak time
display.Image("./21.png")

# %%
# settling time 
display.Image("./22.png")

# %% [markdown]
# 2. examples from lecture 6
# 3. solve Routh w/ const K

# %%
# PZ MAP EXAMPLE
display.Image("./23.png")

# %%
# SOL
# To double the wn but still hold the damping ratio, 
display.Image("./25.jpg")

# %%
# STEP RESPONSE OF UNDERDAMPED SYS
display.Image("./26.png")

# %%
# INVERSE LAPLACE TRANSFORM OF STEP RESPONSE
display.Image("./27.png")

# %%
# RISE TIME 
display.Image("./28.png")

# %%
# PEAK TIME
display.Image("./29.png")

# %%
# MAXIMUM OVERSHOOT
display.Image("./30.png")

# %%
# SETTLING TIME
display.Image("./31.png")
